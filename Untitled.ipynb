# %%
import pandas as pd
from pathlib import Path
import os

# %%
path = "data/"

# %%
files = os.listdir(path)

# %%
print(files)
# Out:
# ['comptage-voyageurs-trains-transilien.csv', 'frequentation-gares.csv', 'gares-de-voyageurs.csv', 'regularite-mensuelle-tgv-aqst.csv']

# %%
comptage_voyageurs = pd.read_csv("data/comptage-voyageurs-trains-transilien.csv", sep=";")
print(comptage_voyageurs.info())
print(comptage_voyageurs.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7328 entries, 0 to 7327
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ﻿Nom Gare          7328 non-null   object
#  1   Code Gare          7328 non-null   int64
#  2   Type jour          7328 non-null   object
#  3   Date               7328 non-null   object
#  4   Annee              7328 non-null   int64
#  5   Ligne              7328 non-null   object
#  6   Axe                7328 non-null   object
#  7   Tranche horaire    7328 non-null   object
#  8   Somme de Montants  7328 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 515.4+ KB
# None
#                     ﻿Nom Gare  Code Gare Type jour        Date  Annee Ligne  \
# 0               ACHERES-VILLE   87381657       DIM  2022-11-20   2022     A
# 1                      BEYNES   87393363       SAM  2024-01-20   2024     N
# ...

# %%
frequentation_gares = pd.read_csv("data/frequentation-gares.csv", sep=";")
print(frequentation_gares.info())
print(frequentation_gares.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3021 entries, 0 to 3020
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Nom de la gare                        3021 non-null   object
#  1   Code UIC                              3021 non-null   int64
#  2   Code postal                           3021 non-null   int64
#  3   Direction Régionale Gares             3010 non-null   object
#  4   Segmentation DRG                      2951 non-null   object
#  5   Segmentation Marketing                2896 non-null   object
#  6   % Non Voyageurs                       3021 non-null   float64
#  7   Total Voyageurs 2024                  3021 non-null   int64
#  8   Total Voyageurs + Non voyageurs 2024  3021 non-null   int64
#  9   Total Voyageurs 2023                  3021 non-null   int64
#  10  Total Voyageurs + Non voyageurs 2023  3021 non-null   int64
# ...

# %%
gares_de_voyageurs = pd.read_csv("data/gares-de-voyageurs.csv", sep=";")
print(gares_de_voyageurs.info())
print(gares_de_voyageurs.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2782 entries, 0 to 2781
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nom                    2782 non-null   object
#  1   Trigramme              2782 non-null   object
#  2   Segment(s) DRG         2782 non-null   object
#  3   Position géographique  2782 non-null   object
#  4   Code commune           2782 non-null   int64
#  5   Code(s) UIC            2782 non-null   object
#  6   id                     2782 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 152.3+ KB
# None
#                      Nom Trigramme Segment(s) DRG   Position géographique  \
# 0              Abancourt       ABT              C   49.6852237, 1.7743058
# 1               Abbaretz       AAR              C  47.5546432, -1.5244159
# 2              Abbeville       ABB              B       50.10221, 1.82449
# ...

# %%
regularite_mensuelle_tgv_aqst = pd.read_csv("data/regularite-mensuelle-tgv-aqst.csv", sep=";")
print(regularite_mensuelle_tgv_aqst.info())
print(regularite_mensuelle_tgv_aqst.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11834 entries, 0 to 11833
# Data columns (total 26 columns):
#  #   Column                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                       --------------  -----
#  0   Date                                                                                         11834 non-null  object
#  1   Service                                                                                      11834 non-null  object
#  2   Gare de départ                                                                               11834 non-null  object
#  3   Gare d'arrivée                                                                               11834 non-null  object
#  4   Durée moyenne du trajet                                                                      11834 non-null  int64
# ...
